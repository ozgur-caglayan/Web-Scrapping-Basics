# %% [markdown]
# # The 100 Richest Internet Entrepreneurs

# %% [markdown]
# ##  by  www.incomediary.com/rich-list

# %%
import pandas as pd

# %%
url =  'https://www.incomediary.com/rich-list'
dfs = pd.read_html(url)

# %%
print(type(dfs))
print(len(dfs))
# Out:
# <class 'list'>
# 1

# %%
top_100_reachest_df=dfs[0]

# %%
top_100_reachest_df.head()
# Out:
#    RANK                                       ENTREPRENEUR         AGE  \
# 0     1  Jeff Bezos  is an American technology and reta...  12/01/1964
# 1     2  Mark Zuckerberg  is an American computer progr...  14/05/1984
# 2     3  Larry Ellison  is an American businessman, ent...  17/08/1944
# 3     4  Larry Page  is an American computer scientist ...  26/03/1973
# 4     5  Sergey Brin  is a Russian-born American comput...  21/08/1973
#
#     WEBSITE     NET WORTH  FOUNDED
# 0    Amazon  8.300000e+10   1994.0
# 1  Facebook  6.330000e+10   2004.0
# 2    Oracle  6.100000e+10   1977.0
# 3    Google  4.930000e+10   1998.0
# 4    Google  4.310000e+10   1998.0

# %%
top_100_reachest_df
# Out:
#      RANK                                       ENTREPRENEUR         AGE  \
# 0       1  Jeff Bezos  is an American technology and reta...  12/01/1964
# 1       2  Mark Zuckerberg  is an American computer progr...  14/05/1984
# 2       3  Larry Ellison  is an American businessman, ent...  17/08/1944
# 3       4  Larry Page  is an American computer scientist ...  26/03/1973
# 4       5  Sergey Brin  is a Russian-born American comput...  21/08/1973
# 5       6  Ma Yun  known professionally as Jack Ma, is a ...  10/09/1964
# 6       7  Ma Huateng  also known as Pony Ma, is a Chines...  29/10/1971
# 7       8  Masayoshi Son  is a Korean-descendant Japanese...  11/08/1957
# 8       9  Azim Premji  is an Indian business tycoon, inv...  24/07/1945
# 9      10  Ding Lei  also known as William Ding, is the f...  01/10/1971
# 10     11  Robin Li  or Li Yanhong is a Chinese Internet ...  17/11/1968
# 11     12  Stephen Cohen  is an American investor, hedge ...  11/06/1956
# ...
